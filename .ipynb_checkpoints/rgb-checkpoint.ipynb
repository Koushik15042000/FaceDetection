# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("thor.jpg")
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x255327CDF60>

# %%
img = np.array(pil)

# %%
img
# Out:
# array([[[ 82,  87,  90],
#         [ 82,  87,  90],
#         [ 82,  87,  90],
#         ...,
#         [101, 106, 110],
#         [101, 106, 110],
#         [101, 106, 110]],
#
#        [[ 82,  87,  90],
#         [ 82,  87,  90],
#         [ 82,  87,  90],
#         ...,
#         [101, 106, 110],
#         [101, 106, 110],
#         [101, 106, 110]],
#
#        [[ 82,  88,  88],
#         [ 82,  88,  88],
#         [ 82,  88,  88],
#         ...,
#         [100, 105, 109],
#         [100, 105, 109],
#         [100, 105, 109]],
#
#        ...,
#
#        [[  9,  23,  32],
#         [  9,  23,  32],
#         [  9,  23,  32],
#         ...,
#         [ 10,   0,   0],
#         [ 10,   0,   0],
#         [ 10,   0,   0]],
#
#        [[  9,  23,  32],
#         [  9,  23,  32],
#         [  9,  23,  32],
#         ...,
#         [ 10,   0,   0],
#         [ 10,   0,   0],
#         [ 10,   0,   0]],
#
#        [[  9,  23,  32],
#         [  9,  23,  32],
#         [  9,  23,  32],
# ...

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
cut = img[:5,:5]
cut
# Out:
# array([[[82, 87, 90],
#         [82, 87, 90],
#         [82, 87, 90],
#         [81, 86, 89],
#         [81, 86, 89]],
#
#        [[82, 87, 90],
#         [82, 87, 90],
#         [82, 87, 90],
#         [81, 86, 89],
#         [81, 86, 89]],
#
#        [[82, 88, 88],
#         [82, 88, 88],
#         [82, 88, 88],
#         [82, 88, 88],
#         [81, 87, 87]],
#
#        [[83, 89, 89],
#         [83, 89, 89],
#         [82, 88, 88],
#         [82, 88, 88],
#         [82, 88, 88]],
#
#        [[83, 89, 89],
#         [83, 89, 89],
#         [83, 89, 89],
#         [82, 88, 88],
#         [82, 88, 88]]], dtype=uint8)

# %%
plt.imshow(cut)
