# %%
import numpy as np

# %%
a = np.random.randint?
# Out:
# Docstring:
# randint(low, high=None, size=None, dtype='l')
#
# Return random integers from `low` (inclusive) to `high` (exclusive).
#
# Return random integers from the "discrete uniform" distribution of
# the specified dtype in the "half-open" interval [`low`, `high`). If
# `high` is None (the default), then results are from [0, `low`).
#
# Parameters
# ----------
# low : int
#     Lowest (signed) integer to be drawn from the distribution (unless
#     ``high=None``, in which case this parameter is one above the
#     *highest* such integer).
# high : int, optional
#     If provided, one above the largest (signed) integer to be drawn
#     from the distribution (see above for behavior if ``high=None``).
# size : int or tuple of ints, optional
#     Output shape.  If the given shape is, e.g., ``(m, n, k)``, then
#     ``m * n * k`` samples are drawn.  Default is None, in which case a
#     single value is returned.
# dtype : dtype, optional
# ...

# %%
a = np.random.randint(1, 10, (2,4))
b = np.random.randint(1, 10, (2,4))

# %%
a
# Out:
# array([[3, 6, 3, 5],
#        [8, 8, 1, 1]])

# %%
b
# Out:
# array([[2, 1, 3, 8],
#        [8, 9, 4, 3]])

# %%
a + b
# Out:
# array([[ 5,  7,  6, 13],
#        [16, 17,  5,  4]])

# %%
a = np.random.randint(1, 10, (3,6))
b = np.random.randint(1, 10, (2,4))

# %%
a + b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-bd58363a63fc> in <module>
# ----> 1 a + b
#
# ValueError: operands could not be broadcast together with shapes (3,6) (2,4)

# %%
a = np.random.randint(1, 10, (4))
b = np.random.randint(1, 10, (2,4))

# %%
a
# Out:
# array([4, 7, 2, 8])

# %%
b
# Out:
# array([[1, 5, 3, 8],
#        [1, 3, 9, 3]])

# %%
a + b
# Out:
# array([[ 5, 12,  5, 16],
#        [ 5, 10, 11, 11]])

# %%
a = np.random.randint(1, 10, (4,2))
b = np.random.randint(1, 10, (2,4))

# %%
a
# Out:
# array([[9, 3],
#        [4, 9],
#        [5, 8],
#        [1, 3]])

# %%
b
# Out:
# array([[7, 3, 7, 8],
#        [9, 5, 8, 9]])

# %%
a + b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-bd58363a63fc> in <module>
# ----> 1 a + b
#
# ValueError: operands could not be broadcast together with shapes (4,2) (2,4)

# %%
a = np.random.randint(1, 10, (2,1))
b = np.random.randint(1, 10, (2,4))

# %%
a
# Out:
# array([[5],
#        [1]])

# %%
b
# Out:
# array([[9, 7, 3, 5],
#        [6, 4, 5, 8]])

# %%
a + b
# Out:
# array([[14, 12,  8, 10],
#        [ 7,  5,  6,  9]])

# %%
a = np.random.randint(1, 10, (300, 2,1))
b = np.random.randint(1, 10, (2,4))

# %%
a
# Out:
# array([[[9],
#         [9]],
#
#        [[6],
#         [7]],
#
#        [[6],
#         [4]],
#
#        [[7],
#         [7]],
#
#        [[8],
#         [6]],
#
#        [[8],
#         [9]],
#
#        [[6],
#         [4]],
#
#        [[1],
#         [5]],
#
#        [[6],
#         [3]],
#
#        [[5],
#         [4]],
#
#        [[9],
#         [9]],
#
#        [[8],
#         [8]],
#
#        [[6],
#         [5]],
#
#        [[4],
#         [3]],
#
#        [[5],
#         [7]],
#
#        [[4],
#         [4]],
#
#        [[4],
#         [4]],
#
#        [[5],
#         [6]],
#
#        [[2],
#         [1]],
#
#        [[8],
#         [6]],
#
#        [[1],
#         [9]],
#
#        [[2],
#         [3]],
#
#        [[9],
#         [6]],
#
#        [[9],
#         [5]],
#
#        [[8],
#         [8]],
#
#        [[6],
#         [2]],
#
#        [[8],
#         [5]],
#
#        [[9],
#         [3]],
#
#        [[5],
#         [7]],
#
#        [[1],
#         [9]],
#
# ...

# %%
b
# Out:
# array([[2, 8, 6, 7],
#        [7, 6, 6, 3]])

# %%
a + b
# Out:
# array([[[11, 17, 15, 16],
#         [16, 15, 15, 12]],
#
#        [[ 8, 14, 12, 13],
#         [14, 13, 13, 10]],
#
#        [[ 8, 14, 12, 13],
#         [11, 10, 10,  7]],
#
#        ...,
#
#        [[ 4, 10,  8,  9],
#         [11, 10, 10,  7]],
#
#        [[ 8, 14, 12, 13],
#         [11, 10, 10,  7]],
#
#        [[10, 16, 14, 15],
#         [ 8,  7,  7,  4]]])

# %%
# Rules of Broadcasting
# Rule 1 : Shape should be same, start checking from right traverse towards left
# Rule 2 : If Shape has got 1, then it will definitely broadcast
